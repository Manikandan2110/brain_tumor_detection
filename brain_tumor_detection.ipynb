# %% [markdown]
# ## Import Necessary Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import tensorflow as tf
from PIL import Image

from sklearn.model_selection import train_test_split

from tensorflow.keras.utils import normalize, to_categorical
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
image_directory='/content/gdrive/MyDrive/brain_tumor_dataset/'

# %% [markdown]
# ## Load Data

# %%
image_directory='/content/gdrive/MyDrive/brain_tumor_dataset/'
no_tumor_images=os.listdir(image_directory+ 'no/')
yes_tumor_images=os.listdir(image_directory+ 'yes/')

print('No Tumor: ', len(no_tumor_images))
print('Tumor: ',len(yes_tumor_images))
# Out:
# No Tumor:  98
# Tumor:  155

# %%
dataset=[]
label=[]

INPUT_SIZE=64

# %% [markdown]
# ## Create labels

# %%
for i , image_name in enumerate(no_tumor_images):
    if(image_name.split('.')[1]=='jpg'):
        image=cv2.imread(image_directory+'no/'+image_name)
        image=Image.fromarray(image,'RGB')
        image=image.resize((INPUT_SIZE,INPUT_SIZE))
        dataset.append(np.array(image))
        label.append(0)

# %%
for i , image_name in enumerate(yes_tumor_images):
    if(image_name.split('.')[1]=='jpg'):
        image=cv2.imread(image_directory+'yes/'+image_name)
        image=Image.fromarray(image, 'RGB')
        image=image.resize((INPUT_SIZE,INPUT_SIZE))
        dataset.append(np.array(image))
        label.append(1)

# %%
dataset=np.array(dataset)
label=np.array(label)

print('Dataset: ',len(dataset))
print('Label: ',len(label))
# Out:
# Dataset:  171
# Label:  171

# %% [markdown]
# ## Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset, label, test_size=0.2, random_state=42)

# %% [markdown]
# ## Normalize the Data

# %%
X_train = normalize(X_train, axis=1)
X_test = normalize(X_test, axis=1)

# %% [markdown]
# ## Model Building

# %%
model=Sequential()

model.add(Conv2D(32, (3,3),activation='relu', input_shape=(INPUT_SIZE, INPUT_SIZE, 3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(32, (3,3),activation='relu', kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3),activation='relu', kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))

# %%
# compile the model
model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ## Model Fit

# %%
r=model.fit(X_train, y_train, 
batch_size=32, 
verbose=1, epochs=100, 
validation_data=(X_test, y_test),
shuffle=False)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 12s 138ms/step - loss: 0.6995 - accuracy: 0.4853 - val_loss: 0.6725 - val_accuracy: 0.6286
# Epoch 2/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6634 - accuracy: 0.6985 - val_loss: 0.6565 - val_accuracy: 0.6571
# Epoch 3/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6402 - accuracy: 0.6618 - val_loss: 0.6224 - val_accuracy: 0.6286
# Epoch 4/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5832 - accuracy: 0.7500 - val_loss: 0.5772 - val_accuracy: 0.6571
# Epoch 5/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5474 - accuracy: 0.7206 - val_loss: 0.5685 - val_accuracy: 0.6000
# Epoch 6/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5086 - accuracy: 0.7721 - val_loss: 0.5644 - val_accuracy: 0.6286
# Epoch 7/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4731 - accuracy: 0.7868 - val_loss: 0.5822 - val_accuracy: 0.6571
# Epoch 8/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4566 - accuracy: 0.8309 - val_loss: 0.5324 - val_accuracy: 0.6857
# Epoch 9/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4608 - accuracy: 0.7647 - val_loss: 0.5376 - val_accuracy: 0.6857
# Epoch 10/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4542 - accuracy: 0.7721 - val_loss: 0.5419 - val_accuracy: 0.7143
# Epoch 11/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4099 - accuracy: 0.8015 - val_loss: 0.5111 - val_accuracy: 0.7429
# Epoch 12/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3866 - accuracy: 0.8235 - val_loss: 0.4983 - val_accuracy: 0.7429
# Epoch 13/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3752 - accuracy: 0.8309 - val_loss: 0.4961 - val_accuracy: 0.7429
# Epoch 14/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3034 - accuracy: 0.8824 - val_loss: 0.5179 - val_accuracy: 0.7143
# Epoch 15/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3434 - accuracy: 0.8456 - val_loss: 0.4915 - val_accuracy: 0.7143
# Epoch 16/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3222 - accuracy: 0.8676 - val_loss: 0.4807 - val_accuracy: 0.7143
# Epoch 17/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2926 - accuracy: 0.9044 - val_loss: 0.4906 - val_accuracy: 0.7143
# Epoch 18/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2832 - accuracy: 0.9044 - val_loss: 0.4432 - val_accuracy: 0.7429
# Epoch 19/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2494 - accuracy: 0.9265 - val_loss: 0.4958 - val_accuracy: 0.7143
# Epoch 20/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1775 - accuracy: 0.9485 - val_loss: 0.4935 - val_accuracy: 0.7429
# Epoch 21/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1968 - accuracy: 0.9338 - val_loss: 0.3805 - val_accuracy: 0.9143
# Epoch 22/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2595 - accuracy: 0.8824 - val_loss: 0.5893 - val_accuracy: 0.6857
# Epoch 23/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1959 - accuracy: 0.9559 - val_loss: 0.3735 - val_accuracy: 0.8000
# Epoch 24/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1754 - accuracy: 0.9559 - val_loss: 0.5718 - val_accuracy: 0.6857
# Epoch 25/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1359 - accuracy: 0.9632 - val_loss: 0.3205 - val_accuracy: 0.9143
# Epoch 26/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1586 - accuracy: 0.9338 - val_loss: 0.6406 - val_accuracy: 0.7143
# Epoch 27/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1334 - accuracy: 0.9485 - val_loss: 0.3106 - val_accuracy: 0.8857
# Epoch 28/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1151 - accuracy: 0.9706 - val_loss: 0.6297 - val_accuracy: 0.7429
# Epoch 29/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1105 - accuracy: 0.9706 - val_loss: 0.3079 - val_accuracy: 0.9143
# Epoch 30/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1192 - accuracy: 0.9632 - val_loss: 0.5302 - val_accuracy: 0.7143
# Epoch 31/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0911 - accuracy: 0.9926 - val_loss: 0.3690 - val_accuracy: 0.7714
# Epoch 32/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0603 - accuracy: 0.9926 - val_loss: 0.3099 - val_accuracy: 0.8857
# Epoch 33/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0607 - accuracy: 0.9853 - val_loss: 0.3865 - val_accuracy: 0.7714
# Epoch 34/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0477 - accuracy: 0.9926 - val_loss: 0.4972 - val_accuracy: 0.7429
# Epoch 35/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0514 - accuracy: 0.9926 - val_loss: 0.3472 - val_accuracy: 0.7714
# Epoch 36/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0545 - accuracy: 0.9926 - val_loss: 0.5219 - val_accuracy: 0.7714
# Epoch 37/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0525 - accuracy: 1.0000 - val_loss: 0.2522 - val_accuracy: 0.9143
# Epoch 38/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0439 - accuracy: 1.0000 - val_loss: 0.4483 - val_accuracy: 0.7714
# Epoch 39/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0380 - accuracy: 0.9926 - val_loss: 0.3656 - val_accuracy: 0.7429
# Epoch 40/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0370 - accuracy: 0.9926 - val_loss: 0.3111 - val_accuracy: 0.7714
# Epoch 41/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0277 - accuracy: 1.0000 - val_loss: 0.5304 - val_accuracy: 0.7714
# Epoch 42/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0246 - accuracy: 0.9926 - val_loss: 0.3803 - val_accuracy: 0.7714
# Epoch 43/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0323 - accuracy: 0.9926 - val_loss: 0.3952 - val_accuracy: 0.7714
# Epoch 44/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.3700 - val_accuracy: 0.7714
# Epoch 45/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.3332 - val_accuracy: 0.7714
# Epoch 46/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.3620 - val_accuracy: 0.7714
# Epoch 47/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0190 - accuracy: 0.9926 - val_loss: 0.2925 - val_accuracy: 0.8286
# Epoch 48/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.4244 - val_accuracy: 0.7714
# Epoch 49/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.3334 - val_accuracy: 0.7714
# Epoch 50/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.2954 - val_accuracy: 0.8571
# Epoch 51/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.5176 - val_accuracy: 0.8000
# Epoch 52/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.5164 - val_accuracy: 0.8000
# Epoch 53/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.3345 - val_accuracy: 0.8000
# Epoch 54/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.3316 - val_accuracy: 0.8000
# Epoch 55/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.4706 - val_accuracy: 0.7714
# Epoch 56/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.4752 - val_accuracy: 0.8000
# Epoch 57/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.3941 - val_accuracy: 0.8000
# Epoch 58/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.3088 - val_accuracy: 0.8000
# Epoch 59/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.3966 - val_accuracy: 0.8000
# Epoch 60/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.7005 - val_accuracy: 0.7714
# Epoch 61/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.4379 - val_accuracy: 0.7714
# Epoch 62/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.3609 - val_accuracy: 0.8000
# Epoch 63/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4320 - val_accuracy: 0.7714
# Epoch 64/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0102 - accuracy: 0.9926 - val_loss: 0.6056 - val_accuracy: 0.7429
# Epoch 65/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4530 - val_accuracy: 0.8000
# Epoch 66/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.4291 - val_accuracy: 0.8000
# Epoch 67/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.5529 - val_accuracy: 0.8286
# Epoch 68/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.7137 - val_accuracy: 0.7714
# Epoch 69/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.4402 - val_accuracy: 0.8000
# Epoch 70/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.3634 - val_accuracy: 0.8000
# Epoch 71/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.5619 - val_accuracy: 0.8000
# Epoch 72/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.4758 - val_accuracy: 0.7714
# Epoch 73/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.3202 - val_accuracy: 0.8286
# Epoch 74/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.3298 - val_accuracy: 0.8286
# Epoch 75/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.4273 - val_accuracy: 0.8000
# Epoch 76/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.6620 - val_accuracy: 0.7714
# Epoch 77/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.7168 - val_accuracy: 0.7714
# Epoch 78/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4641 - val_accuracy: 0.8000
# Epoch 79/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4154 - val_accuracy: 0.8286
# Epoch 80/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4976 - val_accuracy: 0.8000
# Epoch 81/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.9266 - val_accuracy: 0.7714
# Epoch 82/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.9826 - val_accuracy: 0.8000
# Epoch 83/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.6818 - val_accuracy: 0.7714
# Epoch 84/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4516 - val_accuracy: 0.8000
# Epoch 85/100
# 5/5 [==============================] - 0s 22ms/step - loss: 8.0587e-04 - accuracy: 1.0000 - val_loss: 0.3896 - val_accuracy: 0.8286
# Epoch 86/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.5198 - val_accuracy: 0.8000
# Epoch 87/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.9841 - val_accuracy: 0.8000
# Epoch 88/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.8815 - val_accuracy: 0.7714
# Epoch 89/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5975 - val_accuracy: 0.7714
# Epoch 90/100
# 5/5 [==============================] - 0s 19ms/step - loss: 9.9960e-04 - accuracy: 1.0000 - val_loss: 0.4588 - val_accuracy: 0.8286
# Epoch 91/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.7946 - val_accuracy: 0.7714
# Epoch 92/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.0811 - val_accuracy: 0.7714
# Epoch 93/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.6332 - val_accuracy: 0.8286
# Epoch 94/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.3981 - val_accuracy: 0.8000
# Epoch 95/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3451 - val_accuracy: 0.8286
# Epoch 96/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.3590 - val_accuracy: 0.8286
# Epoch 97/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4167 - val_accuracy: 0.8000
# Epoch 98/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.7701 - val_accuracy: 0.8000
# Epoch 99/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.8040 - val_accuracy: 0.8000
# Epoch 100/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.6537 - val_accuracy: 0.8286

# %%
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# %%
plt.plot(r.history['accuracy'], label='train accuracy')
plt.plot(r.history['val_accuracy'], label='val accuracy')
plt.legend()
plt.show()
plt.savefig('AccVal_accuracy')

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, f1_score
#from sklearn.metrics import plot_confusion_matrix

# %%
labels = ['yes,','no']

# %%
#confusion matrix
y_pred=model.predict(X_test)
y_true=y_test
# Out:
# 2/2 [==============================] - 0s 6ms/step

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

actual = numpy.random.binomial(y_test,1)
predicted = numpy.random.binomial(1,y_pred)

confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = ['yes', 'no'])

cm_display.plot()
plt.show()

# %% [markdown]
# ## Save the Model

# %%
model.save('/content/gdrive/MyDrive/brain_tumor_dataset/BrainTumorDetection.h5')

# %% [markdown]
# ## Load Model

# %%
model = load_model('/content/gdrive/MyDrive/brain_tumor_dataset/BrainTumorDetection.h5')

# %% [markdown]
# ## Make Prediction on New Data

# %%
def make_prediction(img):
    
    input_img = np.expand_dims(img, axis=0)
    
    res = (model.predict(input_img) > 0.5).astype("int32")
    return res

# %%
def show_result(img):
    img_path = f"{image_directory}pred/{img}"
    image = cv2.imread(img_path)

    img = Image.fromarray(image)

    img = img.resize((64,64))

    img = np.array(img)
    
    plt.imshow(img)
    plt.show()
    
    pred = make_prediction(img)
    if pred:
        print("yes Tumor Detected")
    else:
        print("No  Tumor Detected")

# %%
show_result('rks.jpeg')
# Out:
# 1/1 [==============================] - 0s 30ms/step
# No  Tumor Detected

# %%
show_result('pred57.jpg')
# Out:
# 1/1 [==============================] - 0s 95ms/step
# No  Tumor Detected
